# %% [markdown]
# # Imports & Data

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import pearsonr
import statsmodels.api as sm

from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

# %%
import pandas as pd
import numpy as np

from sklearn.linear_model import LinearRegression

# %% [markdown]
# ## Training Data

# %%
dataset_url = 'https://github.com/robitussin/CCMACLRL_EXAM/blob/ebd51da1dafde093c18d9e8f35c834d91b2887f7/datasets/train.csv?raw=true'
traindata = pd.read_csv(dataset_url)
traindata.head()
# Out:
#    id  MonsoonIntensity  TopographyDrainage  RiverManagement  Deforestation  \
# 0   0                 5                   8                5              8
# 1   1                 6                   7                4              4
# 2   2                 6                   5                6              7
# 3   3                 3                   4                6              5
# 4   4                 5                   3                2              6
#
#    Urbanization  ClimateChange  DamsQuality  Siltation  AgriculturalPractices  \
# 0             6              4            4          3                      3
# 1             8              8            3          5                      4
# 2             3              7            1          5                      4
# 3             4              8            4          7                      6
# 4             4              4            3          3                      3
#
# ...

# %% [markdown]
# ## Test File

# %%
test_url = 'https://github.com/robitussin/CCMACLRL_EXAM/blob/ebd51da1dafde093c18d9e8f35c834d91b2887f7/datasets/test.csv?raw=true'
testdata = pd.read_csv(test_url)

# %% [markdown]
# # Correlation Visuals

# %% [markdown]
# ## Scatterplot of all

# %%
sns.scatterplot(data=traindata, x='MonsoonIntensity', y='FloodProbability')
plt.title('Scatter Plot: MonsoonIntensity vs FloodProbability')
plt.show()

sns.scatterplot(data=traindata, x='TopographyDrainage', y='FloodProbability')
plt.title('Scatter Plot: TopographyDrainage vs FloodProbability')
plt.show()

sns.scatterplot(data=traindata, x='RiverManagement', y='FloodProbability')
plt.title('Scatter Plot: RiverManagement vs FloodProbability')

sns.scatterplot(data=traindata, x='Deforestation', y='FloodProbability')
plt.title('Scatter Plot: Deforestation vs FloodProbability')
plt.show()

sns.scatterplot(data=traindata, x='Urbanization', y='FloodProbability')
plt.title('Scatter Plot: Urbanization vs FloodProbability')
plt.show()

sns.scatterplot(data=traindata, x='ClimateChange', y='FloodProbability')
plt.title('Scatter Plot: ClimateChange vs FloodProbability')
plt.show()

sns.scatterplot(data=traindata, x='DamsQuality', y='FloodProbability')
plt.title('Scatter Plot: DamsQuality vs FloodProbability')
plt.show()

sns.scatterplot(data=traindata, x='Siltation', y='FloodProbability')
plt.title('Scatter Plot: Urbanization vs FloodProbability')

sns.scatterplot(data=traindata, x='AgriculturalPractices', y='FloodProbability')
plt.title('Scatter Plot: AgriculturalPractices vs FloodProbability')
plt.show()

sns.scatterplot(data=traindata, x='Encroachments', y='FloodProbability')
plt.title('Scatter Plot: Encroachments vs FloodProbability')
plt.show()

sns.scatterplot(data=traindata, x='DrainageSystems', y='FloodProbability')
plt.title('Scatter Plot: DrainageSystems vs FloodProbability')
plt.show()

sns.scatterplot(data=traindata, x='CoastalVulnerability', y='FloodProbability')
plt.title('Scatter Plot: CoastalVulnerability vs FloodProbability')
plt.show()

sns.scatterplot(data=traindata, x='Landslides', y='FloodProbability')
plt.title('Scatter Plot: Landslides vs FloodProbability')
plt.show()

sns.scatterplot(data=traindata, x='Watersheds', y='FloodProbability')
plt.title('Scatter Plot: Watersheds vs FloodProbability')
plt.show()

sns.scatterplot(data=traindata, x='DeterioratingInfrastructure', y='FloodProbability')
plt.title('Scatter Plot: DeterioratingInfrastructure vs FloodProbability')
plt.show()

sns.scatterplot(data=traindata, x='PopulationScore', y='FloodProbability')
plt.title('Scatter Plot: PopulationScore vs FloodProbability')
plt.show()

sns.scatterplot(data=traindata, x='WetlandLoss', y='FloodProbability')
plt.title('Scatter Plot: WetlandLoss vs FloodProbability')
plt.show()

sns.scatterplot(data=traindata, x='InadequatePlanning', y='FloodProbability')
plt.title('Scatter Plot: InadequatePlanning vs FloodProbability')
plt.show()

sns.scatterplot(data=df, x='PoliticalFactors', y='FloodProbability')
plt.title('Scatter Plot: PoliticalFactors vs FloodProbability')
plt.show()

# %% [markdown]
# ## Correlation of Variables

# %%
corr = traindata[traindata.columns[1:]].corr()['FloodProbability'][:]
corr.head(22)
# Out:
# MonsoonIntensity                   0.189098
# TopographyDrainage                 0.187635
# RiverManagement                    0.187131
# Deforestation                      0.184001
# Urbanization                       0.180861
# ClimateChange                      0.184761
# DamsQuality                        0.187996
# Siltation                          0.186789
# AgriculturalPractices              0.183366
# Encroachments                      0.178841
# IneffectiveDisasterPreparedness    0.183109
# DrainageSystems                    0.179305
# CoastalVulnerability               0.177774
# Landslides                         0.185346
# Watersheds                         0.181907
# DeterioratingInfrastructure        0.190007
# PopulationScore                    0.185890
# WetlandLoss                        0.183396
# InadequatePlanning                 0.180968
# PoliticalFactors                   0.182417
# FloodProbability                   1.000000
# ...

# %%
corr = traindata[traindata.columns[1:]].corr()['MonsoonIntensity'][:]
corr.head(22)
# Out:
# MonsoonIntensity                   1.000000
# TopographyDrainage                -0.007362
# RiverManagement                   -0.008070
# Deforestation                     -0.007251
# Urbanization                      -0.009309
# ClimateChange                     -0.008031
# DamsQuality                       -0.007787
# Siltation                         -0.007836
# AgriculturalPractices             -0.008232
# Encroachments                     -0.010309
# IneffectiveDisasterPreparedness   -0.008032
# DrainageSystems                   -0.009716
# CoastalVulnerability              -0.010659
# Landslides                        -0.009121
# Watersheds                        -0.008900
# DeterioratingInfrastructure       -0.008486
# PopulationScore                   -0.008679
# WetlandLoss                       -0.006811
# InadequatePlanning                -0.008155
# PoliticalFactors                  -0.008474
# FloodProbability                   0.189098
# ...

# %% [markdown]
# ## Heatmap

# %%
plt.figure(figsize=(12,10))
sns.heatmap(traindata.corr(), cmap="pink", annot=True, fmt=".2f")
plt.title("Feature Correlation Heatmap")
plt.show()

# %% [markdown]
# # Regression Models

# %% [markdown]
# ## Model 1
# All features
#
# R2 = .844

# %%
X_train = traindata.drop(columns=['FloodProbability'])
y_train = traindata["FloodProbability"]

X_test = testdata

# %%
base_model = LinearRegression()
base_model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ### Model Evaluation

# %%
y_train_pred = model.predict(X_train)

r2 = r2_score(y_train, y_train_pred)
mae = mean_absolute_error(y_train, y_train_pred)
mse = mean_squared_error(y_train, y_train_pred)
rmse = np.sqrt(mse)

print(f"R^2:   {r2:.6f}")
print(f"MAE:   {mae:.6f}")
print(f"MSE:   {mse:.6f}")
print(f"RMSE:  {rmse:.6f}")
# Out:
# R^2:   0.844950
# MAE:   0.015811
# MSE:   0.000404
# RMSE:  0.020092

# %% [markdown]
# ## Model 2
# Remove population score

# %%
X_train_2 = traindata.drop(columns=['FloodProbability'])
y_train_2 = traindata["FloodProbability"]

X_test_2 = testdata

# %%
featuresToDrop = ["PopulationScore", "DeterioratingInfrastructure"]

X_train_2 = X_train_2.drop(columns=featuresToDrop)

X_test_2 = X_test_2.drop(columns=featuresToDrop)

# %%
model_2 = LinearRegression()
model_2.fit(X_train_2, y_train_2)
# Out:
# LinearRegression()

# %% [markdown]
# ### Model Eval

# %%
y_train_pred_2 = model_2.predict(X_train_2)

r2 = r2_score(y_train_2, y_train_pred_2)
mae = mean_absolute_error(y_train_2, y_train_pred_2)
mse = mean_squared_error(y_train_2, y_train_pred_2)
rmse = np.sqrt(mse)

print(f"R^2:   {r2:.6f}")
print(f"MAE:   {mae:.6f}")
print(f"MSE:   {mse:.6f}")
print(f"RMSE:  {rmse:.6f}")
# Out:
# R^2:   0.741274
# MAE:   0.020787
# MSE:   0.000674
# RMSE:  0.025954

# %% [markdown]
# ## Model 3
#
# Remove wetland loss and deteriorating infrastructure

# %%
X_train_3 = traindata.drop(columns=['FloodProbability'])
y_train_3 = traindata["FloodProbability"]

X_test_3 = testdata

# %%
featuresToDrop = ["WetlandLoss", "DeterioratingInfrastructure"]

X_train_3 = X_train_3.drop(columns=featuresToDrop)

X_test_3 = X_test_3.drop(columns=featuresToDrop)

# %%
model_3 = LinearRegression()
model_3.fit(X_train_3, y_train_3)
# Out:
# LinearRegression()

# %% [markdown]
# ### Model Eval

# %%
y_train_pred_3 = model_3.predict(X_train_3)

r2 = r2_score(y_train_3, y_train_pred_3)
mae = mean_absolute_error(y_train_3, y_train_pred_3)
mse = mean_squared_error(y_train_3, y_train_pred_3)
rmse = np.sqrt(mse)

print(f"R^2:   {r2:.6f}")
print(f"MAE:   {mae:.6f}")
print(f"MSE:   {mse:.6f}")
print(f"RMSE:  {rmse:.6f}")
# Out:
# R^2:   0.742431
# MAE:   0.020739
# MSE:   0.000671
# RMSE:  0.025896

# %% [markdown]
# ## Model 4
#
# Use only moonsoon intensity, TopographyDrainage, RiverManagement, and Deforestation

# %%
X_train_4 = traindata.drop(columns=['FloodProbability'])
y_train_4 = traindata["FloodProbability"]

X_test_4 = testdata

# %%
featuresToUse = ["MonsoonIntensity", "TopographyDrainage","RiverManagement","Deforestation"]

X_train_4= X_train_4[featuresToUse]

X_test_4 = X_test_4[featuresToUse]

# %%
model_4 = LinearRegression()
model_4.fit(X_train_4, y_train_4)
# Out:
# LinearRegression()

# %%
y_train_pred_4 = model_4.predict(X_train_4)

r2 = r2_score(y_train_4, y_train_pred_4)
mae = mean_absolute_error(y_train_4, y_train_pred_4)
mse = mean_squared_error(y_train_4, y_train_pred_4)
rmse = np.sqrt(mse)

print(f"R^2:   {r2:.6f}")
print(f"MAE:   {mae:.6f}")
print(f"MSE:   {mse:.6f}")
print(f"RMSE:  {rmse:.6f}")
# Out:
# R^2:   0.143404
# MAE:   0.038046
# MSE:   0.002230
# RMSE:  0.047226

# %% [markdown]
# # Submission File

# %%
sample_submission_url = 'https://github.com/robitussin/CCMACLRL_EXAM/blob/ebd51da1dafde093c18d9e8f35c834d91b2887f7/datasets/sample_submission.csv?raw=true'

samplefile = pd.read_csv(sample_submission_url)

id = samplefile.pop('id')
y_pred = base_model.predict(X_test)

# Create a submission DataFrame
submission_df = pd.DataFrame({
    'id': id,
    'FloodProbability': y_pred
})

# Save the submission DataFrame to a CSV file
submission_df.to_csv('submission_file.csv', index=False)
print("Submission file created: submission_file.csv")
# Out:
# Submission file created: submission_file.csv
