# %% [markdown]
# # Exercise 5: Create your own personal face recognition using SVM

# %% [markdown]
# ## Instructions:
#
# Create a directory in your google drive using this folder structure
#
# ```
# My Drive
# - Images
#   - Train
#     - Elizer
#       - elizerimage1.jpg
#       ...
#     - Eliza
#       - elizaimage1.jpg
#       ...
#     - Elijah
#       - elijahimage1.jpg
#       ...
#   - Test
#     - testimage1.jpg
#     ...
# ```
#
# - Upload 190 images of your self (selfied are recommended) in the Train folder
# - Upload 190 images of your partner in the Train folder
# - Upload 10 images each of yourself and your partner in the Test Folder (30 images total for each member)
# - Use **.png** or **.jpg** or **.jpeg** images files

# %%
# pip install numpy opencv-python scikit-learn
# %pip install pillow pillow-heif pyheif
# Out:
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (11.3.0)
# Collecting pillow-heif
#   Downloading pillow_heif-1.1.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (9.6 kB)
# Collecting pyheif
#   Downloading pyheif-0.8.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.7 kB)
# Requirement already satisfied: cffi>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from pyheif) (2.0.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.0.0->pyheif) (2.23)
# Downloading pillow_heif-1.1.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 47.4 MB/s eta 0:00:00
# Downloading pyheif-0.8.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 69.8 MB/s eta 0:00:00
# Installing collected packages: pillow-heif, pyheif
# Successfully installed pillow-heif-1.1.1 pyheif-0.8.0

# %% [markdown]
# ## Import libraries

# %%
import os
import cv2
import numpy as np
from PIL import Image, UnidentifiedImageError  # Import UnidentifiedImageError
import matplotlib.pyplot as plt
import pyheif

# %% [markdown]
# ## Mount Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## 1. Display one raw image directly from your drive

# %%
def displayImage(image_path):
    try:
        image = Image.open(image_path)
    except UnidentifiedImageError:
        try:
            heif_file = pyheif.read(image_path)
            image = Image.frombytes(
                heif_file.mode,
                heif_file.size,
                heif_file.data,
                "raw",
                heif_file.mode,
                heif_file.stride,
            )
        except Exception as e:
            print(f"Error opening image: {e}")
            return

    plt.imshow(image)
    plt.axis('on')
    plt.show()

displayImage('/content/drive/My Drive/svm-facials/train/matias/IMG_2975.HEIC')

# %% [markdown]
# ## 2. Load the images from your drive and apply preprocessing to your raw images

# %%
# put your answer here
def load_images_from_folder(folder, size=(100,100)):
    images = []
    labels = []

    people = [p for p in os.listdir(folder) if os.path.isdir(os.path.join(folder, p))]
    total = sum(len(os.listdir(os.path.join(folder, p))) for p in people)
    count = 0

    for person_name in people:
        person_folder = os.path.join(folder, person_name)

        for filename in os.listdir(person_folder):
            img_path = os.path.join(person_folder, filename)

            img = cv2.imread(img_path)

            if img is None:
                try:
                    heif_file = pyheif.read(img_path)
                    img = Image.frombytes(
                        heif_file.mode,
                        heif_file.size,
                        heif_file.data,
                        "raw",
                        heif_file.mode,
                        heif_file.stride
                    )
                    img = np.array(img)
                except Exception as e:
                    print(f"Skipping {img_path}: {e}")
                    continue

            if len(img.shape) == 3:
                img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

            img = cv2.resize(img, size)

            images.append(img.flatten())
            labels.append(person_name)

            count += 1
            if count % 10 == 0 or count == total:
                print(f"Processed {count}/{total} images")

    return np.array(images), np.array(labels)

folder = '/content/drive/My Drive/svm-facials/train'
X, y = load_images_from_folder(folder)
print(X.shape, y.shape)
# Out:
# Processed 10/941 images
# Processed 20/941 images
# Processed 30/941 images
# Processed 40/941 images
# Processed 50/941 images
# Processed 60/941 images
# Processed 70/941 images
# Processed 80/941 images
# Processed 90/941 images
# Processed 100/941 images
# Processed 110/941 images
# Processed 120/941 images
# Processed 130/941 images
# Processed 140/941 images
# Processed 150/941 images
# Processed 160/941 images
# Processed 170/941 images
# Processed 180/941 images
# Processed 190/941 images
# Processed 200/941 images
# Processed 210/941 images
# Processed 220/941 images
# Processed 230/941 images
# Processed 240/941 images
# Processed 250/941 images
# Processed 260/941 images
# Processed 270/941 images
# Processed 280/941 images
# Processed 290/941 images
# Processed 300/941 images
# Processed 310/941 images
# Processed 320/941 images
# Processed 330/941 images
# Processed 340/941 images
# Processed 350/941 images
# Processed 360/941 images
# Processed 370/941 images
# Processed 380/941 images
# Processed 390/941 images
# Processed 400/941 images
# Processed 410/941 images
# Processed 420/941 images
# Processed 430/941 images
# Processed 440/941 images
# Processed 450/941 images
# Processed 460/941 images
# Processed 470/941 images
# Processed 480/941 images
# Processed 490/941 images
# Processed 500/941 images
# Processed 510/941 images
# Processed 520/941 images
# Processed 530/941 images
# Processed 540/941 images
# Processed 550/941 images
# Processed 560/941 images
# Processed 570/941 images
# Processed 580/941 images
# Processed 590/941 images
# Processed 600/941 images
# Processed 610/941 images
# Processed 620/941 images
# Processed 630/941 images
# Processed 640/941 images
# Processed 650/941 images
# Processed 660/941 images
# Processed 670/941 images
# Processed 680/941 images
# Processed 690/941 images
# Processed 700/941 images
# Processed 710/941 images
# Processed 720/941 images
# Processed 730/941 images
# Processed 740/941 images
# Processed 750/941 images
# Processed 760/941 images
# Processed 770/941 images
# Processed 780/941 images
# Processed 790/941 images
# Processed 800/941 images
# Processed 810/941 images
# Processed 820/941 images
# Processed 830/941 images
# Processed 840/941 images
# Processed 850/941 images
# Processed 860/941 images
# Processed 870/941 images
# Processed 880/941 images
# Processed 890/941 images
# Processed 900/941 images
# Processed 910/941 images
# Processed 920/941 images
# Processed 930/941 images
# Processed 940/941 images
# Processed 941/941 images
# (941, 10000) (941,)

# %%
images = X
labels = y

# %%
images.shape
# Out:
# (941, 10000)

# %%
labels.shape
# Out:
# (941,)

# %%
labels
# Out:
# array(['matias', 'matias', 'matias', 'matias', 'matias', 'matias',
#        'matias', 'matias', 'matias', 'matias', 'matias', 'matias',
#        'matias', 'matias', 'matias', 'matias', 'matias', 'matias',
#        'matias', 'matias', 'matias', 'matias', 'matias', 'matias',
#        'matias', 'matias', 'matias', 'matias', 'matias', 'matias',
#        'matias', 'matias', 'matias', 'matias', 'matias', 'matias',
#        'matias', 'matias', 'matias', 'matias', 'matias', 'matias',
#        'matias', 'matias', 'matias', 'matias', 'matias', 'matias',
#        'matias', 'matias', 'matias', 'matias', 'matias', 'matias',
#        'matias', 'matias', 'matias', 'matias', 'matias', 'matias',
#        'matias', 'matias', 'matias', 'matias', 'matias', 'matias',
#        'matias', 'matias', 'matias', 'matias', 'matias', 'matias',
#        'matias', 'matias', 'matias', 'matias', 'matias', 'matias',
#        'matias', 'matias', 'matias', 'matias', 'matias', 'matias',
#        'matias', 'matias', 'matias', 'matias', 'matias', 'matias',
#        'matias', 'matias', 'matias', 'matias', 'matias', 'matias',
#        'matias', 'matias', 'matias', 'matias', 'matias', 'matias',
#        'matias', 'matias', 'matias', 'matias', 'matias', 'matias',
#        'matias', 'matias', 'matias', 'matias', 'matias', 'matias',
#        'matias', 'matias', 'matias', 'matias', 'matias', 'matias',
#        'matias', 'matias', 'matias', 'matias', 'matias', 'matias',
#        'matias', 'matias', 'matias', 'matias', 'matias', 'matias',
#        'matias', 'matias', 'matias', 'matias', 'matias', 'matias',
#        'matias', 'matias', 'matias', 'matias', 'matias', 'matias',
#        'matias', 'matias', 'matias', 'matias', 'matias', 'matias',
#        'matias', 'matias', 'matias', 'matias', 'matias', 'matias',
#        'matias', 'matias', 'matias', 'matias', 'matias', 'matias',
#        'matias', 'matias', 'matias', 'matias', 'matias', 'matias',
#        'matias', 'matias', 'matias', 'matias', 'matias', 'matias',
#        'matias', 'matias', 'matias', 'matias', 'matias', 'matias',
#        'matias', 'matias', 'matias', 'matias', 'matias', 'matias',
#        'matias', 'matias', 'matias', 'matias', 'matias', 'matias',
#        'matias', 'matias', 'matias', 'matias', 'matias', 'matias',
#        'matias', 'matias', 'matias', 'matias', 'matias', 'matias',
#        'matias', 'matias', 'matias', 'matias', 'matias', 'matias',
#        'matias', 'matias', 'matias', 'matias', 'matias', 'matias',
#        'matias', 'matias', 'matias', 'matias', 'matias', 'matias',
#        'matias', 'matias', 'matias', 'matias', 'matias', 'matias',
#        'matias', 'matias', 'matias', 'matias', 'matias', 'matias',
#        'matias', 'matias', 'matias', 'matias', 'matias', 'matias',
#        'matias', 'matias', 'matias', 'matias', 'matias', 'matias',
#        'matias', 'matias', 'matias', 'matias', 'matias', 'matias',
#        'matias', 'matias', 'matias', 'matias', 'matias', 'matias',
#        'matias', 'matias', 'matias', 'matias', 'matias', 'matias',
#        'matias', 'matias', 'matias', 'matias', 'matias', 'matias',
#        'matias', 'matias', 'matias', 'matias', 'matias', 'matias',
#        'matias', 'matias', 'matias', 'matias', 'matias', 'matias',
#        'matias', 'matias', 'matias', 'matias', 'matias', 'matias',
#        'matias', 'matias', 'matias', 'matias', 'matias', 'matias',
#        'matias', 'matias', 'matias', 'matias', 'matias', 'matias',
#        'matias', 'matias', 'matias', 'matias', 'matias', 'matias',
#        'matias', 'matias', 'matias', 'matias', 'matias', 'matias',
#        'matias', 'matias', 'matias', 'matias', 'matias', 'matias',
#        'matias', 'matias', 'matias', 'matias', 'matias', 'matias',
#        'matias', 'matias', 'matias', 'matias', 'matias', 'matias',
#        'matias', 'matias', 'matias', 'matias', 'matias', 'matias',
#        'matias', 'matias', 'matias', 'matias', 'matias', 'matias',
#        'matias', 'matias', 'matias', 'matias', 'matias', 'matias',
#        'matias', 'matias', 'matias', 'matias', 'matias', 'matias',
#        'matias', 'matias', 'matias', 'matias', 'matias', 'matias',
#        'matias', 'matias', 'matias', 'matias', 'matias', 'matias',
#        'matias', 'matias', 'matias', 'matias', 'matias', 'matias',
#        'matias', 'matias', 'matias', 'matias', 'matias', 'matias',
#        'matias', 'matias', 'matias', 'matias', 'matias', 'matias',
#        'matias', 'matias', 'matias', 'matias', 'matias', 'matias',
#        'matias', 'matias', 'matias', 'matias', 'matias', 'matias',
#        'matias', 'matias', 'matias', 'matias', 'matias', 'matias',
#        'matias', 'matias', 'matias', 'matias', 'matias', 'matias',
#        'matias', 'matias', 'matias', 'matias', 'matias', 'matias',
#        'matias', 'matias', 'matias', 'matias', 'matias', 'matias',
#        'matias', 'matias', 'matias', 'matias', 'matias', 'matias',
#        'matias', 'matias', 'matias', 'matias', 'matias', 'matias',
#        'matias', 'matias', 'matias', 'matias', 'matias', 'matias',
#        'matias', 'matias', 'matias', 'matias', 'matias', 'matias',
#        'matias', 'matias', 'matias', 'matias', 'matias', 'matias',
#        'matias', 'matias', 'anastacio', 'anastacio', 'anastacio',
#        'anastacio', 'anastacio', 'anastacio', 'anastacio', 'anastacio',
#        'anastacio', 'anastacio', 'anastacio', 'anastacio', 'anastacio',
#        'anastacio', 'anastacio', 'anastacio', 'anastacio', 'anastacio',
#        'anastacio', 'anastacio', 'anastacio', 'anastacio', 'anastacio',
#        'anastacio', 'anastacio', 'anastacio', 'anastacio', 'anastacio',
#        'anastacio', 'anastacio', 'anastacio', 'anastacio', 'anastacio',
#        'anastacio', 'anastacio', 'anastacio', 'anastacio', 'anastacio',
#        'anastacio', 'anastacio', 'anastacio', 'anastacio', 'anastacio',
#        'anastacio', 'anastacio', 'anastacio', 'anastacio', 'anastacio',
#        'anastacio', 'anastacio', 'anastacio', 'anastacio', 'anastacio',
#        'anastacio', 'anastacio', 'anastacio', 'anastacio', 'anastacio',
#        'anastacio', 'anastacio', 'anastacio', 'anastacio', 'anastacio',
#        'anastacio', 'anastacio', 'anastacio', 'anastacio', 'anastacio',
#        'anastacio', 'anastacio', 'anastacio', 'anastacio', 'anastacio',
#        'anastacio', 'anastacio', 'anastacio', 'anastacio', 'anastacio',
#        'anastacio', 'anastacio', 'anastacio', 'anastacio', 'anastacio',
#        'anastacio', 'anastacio', 'anastacio', 'anastacio', 'anastacio',
#        'anastacio', 'anastacio', 'anastacio', 'anastacio', 'anastacio',
#        'anastacio', 'anastacio', 'anastacio', 'anastacio', 'anastacio',
#        'anastacio', 'anastacio', 'anastacio', 'anastacio', 'anastacio',
#        'anastacio', 'anastacio', 'anastacio', 'anastacio', 'anastacio',
#        'anastacio', 'anastacio', 'anastacio', 'anastacio', 'anastacio',
#        'anastacio', 'anastacio', 'anastacio', 'anastacio', 'anastacio',
#        'anastacio', 'anastacio', 'anastacio', 'anastacio', 'anastacio',
#        'anastacio', 'anastacio', 'anastacio', 'anastacio', 'anastacio',
#        'anastacio', 'anastacio', 'anastacio', 'anastacio', 'anastacio',
#        'anastacio', 'anastacio', 'anastacio', 'anastacio', 'anastacio',
#        'anastacio', 'anastacio', 'anastacio', 'anastacio', 'anastacio',
#        'anastacio', 'anastacio', 'anastacio', 'anastacio', 'anastacio',
#        'anastacio', 'anastacio', 'anastacio', 'anastacio', 'anastacio',
#        'anastacio', 'anastacio', 'anastacio', 'anastacio', 'anastacio',
#        'anastacio', 'anastacio', 'anastacio', 'anastacio', 'anastacio',
#        'anastacio', 'anastacio', 'anastacio', 'anastacio', 'anastacio',
#        'anastacio', 'anastacio', 'anastacio', 'anastacio', 'anastacio',
#        'anastacio', 'anastacio', 'anastacio', 'anastacio', 'anastacio',
#        'anastacio', 'anastacio', 'anastacio', 'anastacio', 'anastacio',
#        'anastacio', 'anastacio', 'anastacio', 'anastacio', 'anastacio',
#        'anastacio', 'anastacio', 'anastacio', 'anastacio', 'anastacio',
#        'anastacio', 'anastacio', 'anastacio', 'anastacio', 'anastacio',
#        'anastacio', 'anastacio', 'anastacio', 'anastacio', 'anastacio',
#        'anastacio', 'anastacio', 'anastacio', 'anastacio', 'anastacio',
#        'anastacio', 'anastacio', 'anastacio', 'anastacio', 'anastacio',
#        'anastacio', 'anastacio', 'anastacio', 'anastacio', 'anastacio',
#        'anastacio', 'anastacio', 'anastacio', 'anastacio', 'anastacio',
#        'anastacio', 'anastacio', 'anastacio', 'anastacio', 'anastacio',
#        'anastacio', 'anastacio', 'anastacio', 'anastacio', 'anastacio',
#        'anastacio', 'anastacio', 'anastacio', 'anastacio', 'anastacio',
#        'anastacio', 'anastacio', 'anastacio', 'anastacio', 'anastacio',
#        'anastacio', 'anastacio', 'anastacio', 'anastacio', 'anastacio',
#        'anastacio', 'anastacio', 'anastacio', 'anastacio', 'anastacio',
#        'anastacio', 'anastacio', 'anastacio', 'anastacio', 'anastacio',
#        'anastacio', 'anastacio', 'anastacio', 'anastacio', 'anastacio',
#        'anastacio', 'anastacio', 'anastacio', 'anastacio', 'anastacio',
#        'anastacio', 'anastacio', 'anastacio', 'anastacio', 'anastacio',
#        'anastacio', 'anastacio', 'anastacio', 'anastacio', 'anastacio',
#        'anastacio', 'anastacio', 'anastacio', 'anastacio', 'anastacio',
#        'anastacio', 'anastacio', 'anastacio', 'anastacio', 'anastacio',
#        'anastacio', 'anastacio', 'anastacio', 'anastacio', 'anastacio',
#        'anastacio', 'anastacio', 'anastacio', 'anastacio', 'anastacio',
#        'anastacio', 'cadiz', 'cadiz', 'cadiz', 'cadiz', 'cadiz', 'cadiz',
#        'cadiz', 'cadiz', 'cadiz', 'cadiz', 'cadiz', 'cadiz', 'cadiz',
#        'cadiz', 'cadiz', 'cadiz', 'cadiz', 'cadiz', 'cadiz', 'cadiz',
#        'cadiz', 'cadiz', 'cadiz', 'cadiz', 'cadiz', 'cadiz', 'cadiz',
#        'cadiz', 'cadiz', 'cadiz', 'cadiz', 'cadiz', 'cadiz', 'cadiz',
#        'cadiz', 'cadiz', 'cadiz', 'cadiz', 'cadiz', 'cadiz', 'cadiz',
#        'cadiz', 'cadiz', 'cadiz', 'cadiz', 'cadiz', 'cadiz', 'cadiz',
#        'cadiz', 'cadiz', 'cadiz', 'cadiz', 'cadiz', 'cadiz', 'cadiz',
#        'cadiz', 'cadiz', 'cadiz', 'cadiz', 'cadiz', 'cadiz', 'cadiz',
#        'cadiz', 'cadiz', 'cadiz', 'cadiz', 'cadiz', 'cadiz', 'cadiz',
#        'cadiz', 'cadiz', 'cadiz', 'cadiz', 'cadiz', 'cadiz', 'cadiz',
#        'cadiz', 'cadiz', 'cadiz', 'cadiz', 'cadiz', 'cadiz', 'cadiz',
#        'cadiz', 'cadiz', 'cadiz', 'cadiz', 'cadiz', 'cadiz', 'cadiz',
#        'cadiz', 'cadiz', 'cadiz', 'cadiz', 'cadiz', 'cadiz', 'cadiz',
#        'cadiz', 'cadiz', 'cadiz', 'cadiz', 'cadiz', 'cadiz', 'cadiz',
#        'cadiz', 'cadiz', 'cadiz', 'cadiz', 'cadiz', 'cadiz', 'cadiz',
#        'cadiz', 'cadiz', 'cadiz', 'cadiz', 'cadiz', 'cadiz', 'cadiz',
#        'cadiz', 'cadiz', 'cadiz', 'cadiz', 'cadiz', 'cadiz', 'cadiz',
#        'cadiz', 'cadiz', 'cadiz', 'cadiz', 'cadiz', 'cadiz', 'cadiz',
#        'cadiz', 'cadiz', 'cadiz', 'cadiz', 'cadiz', 'cadiz', 'cadiz',
#        'cadiz', 'cadiz', 'cadiz', 'cadiz', 'cadiz', 'cadiz', 'cadiz',
#        'cadiz', 'cadiz', 'cadiz', 'cadiz', 'cadiz', 'cadiz', 'cadiz',
#        'cadiz', 'cadiz', 'cadiz', 'cadiz', 'cadiz', 'cadiz', 'cadiz',
#        'cadiz', 'cadiz', 'cadiz', 'cadiz', 'cadiz', 'cadiz', 'cadiz',
#        'cadiz', 'cadiz', 'cadiz', 'cadiz', 'cadiz', 'cadiz', 'cadiz',
#        'cadiz', 'cadiz', 'cadiz', 'cadiz', 'cadiz', 'cadiz', 'cadiz',
#        'cadiz', 'cadiz', 'cadiz', 'cadiz', 'cadiz', 'cadiz', 'cadiz',
#        'cadiz', 'cadiz'], dtype='<U9')

# %% [markdown]
# ## 3. Display one pre-processed image from the training set

# %%
# put your answer here
# Get a sample image and its corresponding name
image = images[0].reshape(100,100)  # Access the first image
name = labels[0]  # Get the name corresponding to the image

# Display the image
plt.imshow(image, cmap="gray")
plt.title(name)
plt.axis('on')  # Hide axes
plt.show()

# %% [markdown]
# ## 4. Display ten pre-processed images from the training set

# %%
# put your answer here
num_faces = 10

fig, axes = plt.subplots(2, 5, figsize=(15, 6))  # 2 rows and 5 columns
axes = axes.flatten()  # Flatten the array of axes for easy indexing

# Loop to display the images
for i in range(num_faces):
    image = images[i].reshape(100,100)  # Access the i-th image
    name = labels[i]  # Get the name corresponding to the image

    axes[i].imshow(image, cmap='gray')  # Show the image
    axes[i].set_title(name)  # Set the title to the name
    axes[i].axis('on')  # Hide axes

# Adjust layout
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 5. Split your training data

# %%
# put your answer here
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(images, labels, test_size=0.2, random_state=42)

# %% [markdown]
# ## 6. Train your SVM model

# %%
# put your answer here
from sklearn import svm

model = svm.SVC(gamma='scale')  # You can choose different kernels like 'linear', 'rbf', etc.
model.fit(X_train, y_train)
# Out:
# SVC()

# %% [markdown]
# ## 7. Evaluate your SVM model

# %%
# put your answer here
from sklearn.metrics import accuracy_score

y_pred = model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy * 100:.2f}%')
# Out:
# Accuracy: 99.47%

# %% [markdown]
# ## 8. Test your model using images not in your training set

# %% [markdown]
# Use your SVM model to predict the label of all of your images in the Test folder

# %%
def displayImage(image_path):
    try:
        image = Image.open(image_path)
    except UnidentifiedImageError:
        try:
            heif_file = pyheif.read(image_path)
            image = Image.frombytes(
                heif_file.mode,
                heif_file.size,
                heif_file.data,
                "raw",
                heif_file.mode,
                heif_file.stride,
            )
        except Exception as e:
            print(f"Error opening image: {e}")
            return

    plt.imshow(image)
    plt.axis('on')
    plt.show()

# %%
# put your answer here
def predict_image(img_path, model):
    img = cv2.imread(img_path)

    if img is None:
        try:
            heif_file = pyheif.read(img_path)
            img = Image.frombytes(
                heif_file.mode,
                heif_file.size,
                heif_file.data,
                "raw",
                heif_file.mode,
                heif_file.stride
            )
            img = np.array(img)
        except Exception as e:
            print(f"Error opening image: {e}")
            return None # Return None if image can't be opened


    if len(img.shape) == 3:
        img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

    img = cv2.resize(img, (100, 100)).flatten().reshape(1, -1)  # Flatten and reshape for prediction
    prediction = model.predict(img)
    return prediction

# %% [markdown]
# # Predictions

# %%
import glob

files = glob.glob("/content/drive/MyDrive/svm-facials/test/*.HEIC")
print("Files found:", files)

bilang = 0
for file in files:
    if (x := predict_image(file, model)) == 'anastacio':
      bilang += 1
      print('This is Anastacio', x, 'count:', bilang)
      displayImage(file)
    elif (x := predict_image(file, model)) == 'cadiz':
      bilang += 1
      print('This is Cadiz', x,  'count:',  bilang)
      displayImage(file)
    elif (x := predict_image(file, model)) == 'matias':
      bilang += 1
      print('This is Matias', x, 'count:', bilang)
      displayImage(file)
# Out:
# Files found: ['/content/drive/MyDrive/svm-facials/test/Copy of IMG_2996.HEIC', '/content/drive/MyDrive/svm-facials/test/Copy of IMG_2998.HEIC', '/content/drive/MyDrive/svm-facials/test/Copy of IMG_2999 (1).HEIC', '/content/drive/MyDrive/svm-facials/test/Copy of IMG_3002 (1).HEIC', '/content/drive/MyDrive/svm-facials/test/Copy of IMG_2994.HEIC', '/content/drive/MyDrive/svm-facials/test/Copy of IMG_2997.HEIC', '/content/drive/MyDrive/svm-facials/test/Copy of IMG_3001 (1).HEIC', '/content/drive/MyDrive/svm-facials/test/Copy of IMG_3004 (1).HEIC', '/content/drive/MyDrive/svm-facials/test/Copy of IMG_3003.HEIC', '/content/drive/MyDrive/svm-facials/test/Copy of IMG_2993.HEIC', '/content/drive/MyDrive/svm-facials/test/Copy of IMG_6379.HEIC', '/content/drive/MyDrive/svm-facials/test/Copy of IMG_6408.HEIC', '/content/drive/MyDrive/svm-facials/test/Copy of IMG_6350.HEIC', '/content/drive/MyDrive/svm-facials/test/Copy of IMG_6381.HEIC', '/content/drive/MyDrive/svm-facials/test/Copy of IMG_6380.HEIC', '/content/drive/MyDrive/svm-facials/test/Copy of IMG_6348.HEIC', '/content/drive/MyDrive/svm-facials/test/Copy of IMG_6347.HEIC', '/content/drive/MyDrive/svm-facials/test/Copy of IMG_6284.HEIC', '/content/drive/MyDrive/svm-facials/test/Copy of IMG_3007.HEIC', '/content/drive/MyDrive/svm-facials/test/Copy of IMG_3001.HEIC', '/content/drive/MyDrive/svm-facials/test/Copy of IMG_3004.HEIC', '/content/drive/MyDrive/svm-facials/test/Copy of IMG_3005.HEIC', '/content/drive/MyDrive/svm-facials/test/Copy of IMG_3008.HEIC', '/content/drive/MyDrive/svm-facials/test/Copy of IMG_3002.HEIC', '/content/drive/MyDrive/svm-facials/test/Copy of IMG_3006.HEIC', '/content/drive/MyDrive/svm-facials/test/Copy of IMG_3010.HEIC', '/content/drive/MyDrive/svm-facials/test/Copy of IMG_3009.HEIC', '/content/drive/MyDrive/svm-facials/test/Copy of IMG_2999.HEIC']
# This is Matias ['matias'] count: 1
# This is Matias ['matias'] count: 2
# This is Matias ['matias'] count: 3
# This is Matias ['matias'] count: 4
# This is Matias ['matias'] count: 5
# This is Matias ['matias'] count: 6
# This is Matias ['matias'] count: 7
# This is Matias ['matias'] count: 8
# This is Matias ['matias'] count: 9
# This is Matias ['matias'] count: 10
# This is Cadiz ['cadiz'] count: 11
# This is Matias ['matias'] count: 12
# This is Cadiz ['cadiz'] count: 13
# This is Cadiz ['cadiz'] count: 14
# This is Cadiz ['cadiz'] count: 15
# This is Cadiz ['cadiz'] count: 16
# This is Cadiz ['cadiz'] count: 17
# This is Cadiz ['cadiz'] count: 18
# This is Anastacio ['anastacio'] count: 19
# This is Cadiz ['cadiz'] count: 20
# This is Anastacio ['anastacio'] count: 21
# This is Anastacio ['anastacio'] count: 22
# This is Anastacio ['anastacio'] count: 23
# This is Anastacio ['anastacio'] count: 24
# This is Anastacio ['anastacio'] count: 25
# This is Anastacio ['anastacio'] count: 26
# This is Anastacio ['anastacio'] count: 27
# This is Anastacio ['anastacio'] count: 28

# %%
if (x := predict_image('/content/drive/My Drive/svm-facials/train/anastacio/IMG_3014.HEIC', model)) == 'anastacio':
    print('This is Anastacio', x)
    displayImage('/content/drive/My Drive/svm-facials/train/anastacio/IMG_3014.HEIC')
else:
    print('This is not Anastacio', x)
# Out:
# This is Anastacio ['anastacio']

# %%
if (x := predict_image('/content/drive/My Drive/svm-facials/train/cadiz/IMG_9097.HEIC', model)) == 'cadiz':
    print('This is Cadiz', x)
    displayImage('/content/drive/My Drive/svm-facials/train/cadiz/IMG_9097.HEIC')
else:
    print('This is not Cadiz', x)
# Out:
# This is Cadiz ['cadiz']
